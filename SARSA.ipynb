# %%
# !pip install gymnasium
# Out:
# ...
#    ---------------------------------------- 0.0/952.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/952.1 kB ? eta -:--:--
#    ---------------------- ----------------- 524.3/952.1 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 952.1/952.1 kB 2.3 MB/s  0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
#    -------------------- ------------------- 1/2 [gymnasium]
# ...

# %%
# !pip install "gymnasium[toy-text]"
# Out:
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.6 MB 2.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/10.6 MB 3.0 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/10.6 MB 3.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/10.6 MB 3.2 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/10.6 MB 3.2 MB/s eta 0:00:03
#    --------------- ------------------------ 4.2/10.6 MB 3.2 MB/s eta 0:00:03
#    ------------------ --------------------- 5.0/10.6 MB 3.2 MB/s eta 0:00:02
#    --------------------- ------------------ 5.8/10.6 MB 3.2 MB/s eta 0:00:02
#    ------------------------ --------------- 6.6/10.6 MB 3.3 MB/s eta 0:00:02
#    -------------------------- ------------- 7.1/10.6 MB 3.3 MB/s eta 0:00:02
# ...

# %%
import gymnasium as gym
import random 
import numpy as np

# %%
# sample env
