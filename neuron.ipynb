# %%
# !pip install torch torchvision torchaudio
# Out:
# Collecting torch
#   Using cached torch-2.11.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Using cached torchvision-0.26.0-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.11.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: filelock in c:\users\ranas\anaconda3\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ranas\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\ranas\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ranas\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ranas\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\ranas\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\ranas\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: numpy in c:\users\ranas\anaconda3\lib\site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\ranas\anaconda3\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ranas\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ranas\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Using cached torch-2.11.0-cp313-cp313-win_amd64.whl (114.6 MB)
# Using cached torchvision-0.26.0-cp313-cp313-win_amd64.whl (4.3 MB)
# Downloading torchaudio-2.11.0-cp313-cp313-win_amd64.whl (328 kB)
# Installing collected packages: torchaudio, torch, torchvision
#
#    ---------------------------------------- 0/3 [torchaudio]
#    ---------------------------------------- 0/3 [torchaudio]
#    ---------------------------------------- 0/3 [torchaudio]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    ------------- -------------------------- 1/3 [torch]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchvision]
#    ---------------------------------------- 3/3 [torchvision]
#
# Successfully installed torch-2.11.0 torchaudio-2.11.0 torchvision-0.26.0

# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cpu

# %%
import torch 
import torch.nn as nn

# %%
#inputs
inputs=torch.tensor([1.0,2.0,3.0])

# %%
torch.manual_seed(42)
neuron=nn.Linear(in_features=3,out_features=1)
output=neuron(inputs)

# %%
output
# Out:
# tensor([1.5244], grad_fn=<ViewBackward0>)

# %%
neuron.bias
# Out:
# Parameter containing:
# tensor([0.5304], requires_grad=True)

# %%
neuron.weight
# Out:
# Parameter containing:
# tensor([[ 0.4414,  0.4792, -0.1353]], requires_grad=True)

# %%
#verify formula
neuron.weight@inputs+neuron.bias
# Out:
# tensor([1.5244], grad_fn=<AddBackward0>)
